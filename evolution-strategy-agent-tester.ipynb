# %%
ticker = "GME"
TESTING = True

# %%
API_KEY =  '0MXZO7Y5VXKK2R3PXN5XH8EZEWJTG6BJ' + '@AMER.OAUTHAP'
ACCT_NUMBER = '255612401'
CALLBACK_URL = 'https://localhost:8888'

# %%
import numpy as np
import pandas as pd
import time
import matplotlib.pyplot as plt
import seaborn as sns
import random


from tda import auth, client
from tda.orders.equities import equity_buy_market, equity_sell_market
from tda.orders.common import Duration, Session
from webdriver_manager.chrome import ChromeDriverManager
import datetime as dt
from datetime import datetime
import json
import schedule
import time
from dateutil.relativedelta import relativedelta

sns.set()

# %%
import pkg_resources
import types

def get_imports():
    for name, val in globals().items():
        if isinstance(val, types.ModuleType):
            name = val.__name__.split('.')[0]
        elif isinstance(val, type):
            name = val.__module__.split('.')[0]
        poorly_named_packages = {'PIL': 'Pillow', 'sklearn': 'scikit-learn'}
        if name in poorly_named_packages.keys():
            name = poorly_named_packages[name]
        yield name


imports = list(set(get_imports()))
requirements = []
for m in pkg_resources.working_set:
    if m.project_name in imports and m.project_name != 'pip':
        requirements.append((m.project_name, m.version))

#for r in requirements:
#    print('{}=={}'.format(*r))

# %%
class Deep_Evolution_Strategy:

    inputs = None

    def __init__(
        self, weights, reward_function, population_size, sigma, learning_rate
    ):
        self.weights = weights
        self.reward_function = reward_function
        self.population_size = population_size
        self.sigma = sigma
        self.learning_rate = learning_rate

    def _get_weight_from_population(self, weights, population):
        weights_population = []
        for index, i in enumerate(population):
            jittered = self.sigma * i
            weights_population.append(weights[index] + jittered)
        return weights_population

    def get_weights(self):
        return self.weights

    def train(self, epoch = 100, print_every = 1):
        lasttime = time.time()
        for i in range(epoch):
            population = []
            rewards = np.zeros(self.population_size)
            for k in range(self.population_size):
                x = []
                for w in self.weights:
                    x.append(np.random.randn(*w.shape))
                population.append(x)
            for k in range(self.population_size):
                weights_population = self._get_weight_from_population(
                    self.weights, population[k]
                )
                rewards[k] = self.reward_function(weights_population)
            rewards = (rewards - np.mean(rewards)) / (np.std(rewards) + 1e-7)
            for index, w in enumerate(self.weights):
                A = np.array([p[index] for p in population])
                self.weights[index] = (
                    w
                    + self.learning_rate
                    / (self.population_size * self.sigma)
                    * np.dot(A.T, rewards).T
                )
            if (i + 1) % print_every == 0:
                print(
                    'iter %d. reward: %f'
                    % (i + 1, self.reward_function(self.weights))
                )
        print('time taken to train:', time.time() - lasttime, 'seconds')


class Model:
    def __init__(self, input_size, layer_size, output_size):
        self.weights = [
            np.random.randn(input_size, layer_size),
            np.random.randn(layer_size, output_size),
            np.random.randn(1, layer_size),
        ]

    def predict(self, inputs):
        feed = np.dot(inputs, self.weights[0]) + self.weights[-1]
        decision = np.dot(feed, self.weights[1])
        return decision

    def get_weights(self):
        return self.weights

    def set_weights(self, weights):
        self.weights = weights

# %%
class Agent:

    POPULATION_SIZE = 90 #15
    SIGMA = 0.1
    LEARNING_RATE = 0.03

    def __init__(self, model, window_size, trend, skip, initial_money):
        self.model = model
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        self.initial_money = initial_money
        self.es = Deep_Evolution_Strategy(
            self.model.get_weights(),
            self.get_reward,
            self.POPULATION_SIZE,
            self.SIGMA,
            self.LEARNING_RATE,
        )

    
    def act(self, sequence):
        decision = self.model.predict(np.array(sequence))
        return np.argmax(decision[0])
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array([res])

    def get_reward(self, weights):
        initial_money = self.initial_money
        starting_money = initial_money
        self.model.weights = weights
        state = self.get_state(0)
        inventory = []
        quantity = 0
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and starting_money >= self.trend[t]:
                inventory.append(self.trend[t])
                starting_money -= close[t]
                
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                starting_money += self.trend[t]

            state = next_state
        return ((starting_money - initial_money) / initial_money) * 100

    def fit(self, iterations, checkpoint):
        self.es.train(iterations, print_every = checkpoint)

    def buy(self,  current_inventory, current_price, days_since_training):
        #initial_money = self.initial_money
        state = self.get_state(days_since_training)
        starting_money = self.initial_money
        sell = False
        buy = False
    
        inventory = current_inventory
        action = self.act(state)
        
        if action == 1 and self.initial_money >= current_price: #self.trend[t]:
            inventory.append(current_price)
            # print('starting_money ' + str(starting_money))
            self.initial_money -= current_price
            # print('self.initial_money ' + str(self.initial_money))
            # print('current_price ' + str(current_price))
            # print('buy 1 unit at price %f, total balance %f'% (current_price, self.initial_money))
            
            buy = True
        elif action == 2 and len(inventory):
            bought_price = inventory.pop(0)
            self.initial_money += current_price#self.trend[t]
            try:
                invest = ((current_price - bought_price) / bought_price) * 100
            except:
                invest = 0
            print('sell 1 unit at price %f, investment %f %%, total balance %f,' % (current_price, invest, self.initial_money) )
            sell = True

        invest = ((self.initial_money - starting_money) / starting_money) * 100
        total_gains = self.initial_money - starting_money
        #self.initial_money = initial_money
        return inventory, buy, sell, total_gains, invest

# %%
class TDAmeritrade:
    
    def __init__(self, account_number, api_key, callback_url, symbol):
        token_path = 'token.pickle'
        self.SYMBOL = symbol
        self.API_KEY = api_key
        self.CALLBACK_URL = callback_url
        self.ACCOUNT_NUMBER = account_number
        try:
            self.c = auth.client_from_token_file(token_path, self.API_KEY)
        except FileNotFoundError:
            from selenium import webdriver
            with webdriver.Chrome(ChromeDriverManager().install()) as driver:
                self.c = auth.client_from_login_flow(
                    driver, self.API_KEY, self.CALLBACK_URL, token_path)

        return
    
    def get_prices(self, end):

        # fetch price history using tda-api
        r = self.c.get_price_history(self.SYMBOL,
                                period_type=client.Client.PriceHistory.PeriodType.DAY,
                                period=client.Client.PriceHistory.Period.THREE_DAYS,
                                frequency_type=client.Client.PriceHistory.FrequencyType.MINUTE,
                                frequency=client.Client.PriceHistory.Frequency.EVERY_THIRTY_MINUTES,
                                end_datetime=end,
                                need_extended_hours_data=False
                                )

        assert r.status_code == 200, r.raise_for_status()

        # parse json and get candles data
        y = r.json()
        y = y["candles"]
        y = json.dumps(y)
        df = pd.read_json(y)
        # drop last row
        df = df[:-1]

        return df
    
    def get_daily_price_history(self, symbol, start_date, end_date):
        r = self.c.get_price_history_every_day(symbol=symbol, start_datetime=start_date, end_datetime=end_date)
        assert r.status_code == 200, r.raise_for_status()

        y = r.json()
        y = y["candles"]
        y = json.dumps(y)
       
        df = pd.read_json(y)        
        return df

    def get_cur_price(self):

        r = self.c.get_quote(self.SYMBOL)
        assert r.status_code == 200, r.raise_for_status()

        y = r.json()
        price = y[self.SYMBOL]["lastPrice"]

        return price

    # get useful account info


    def get_account(self):

        r = self.c.get_account(self.ACCOUNT_NUMBER)
        assert r.status_code == 200, r.raise_for_status()

        y = r.json()

        return y

    # see if we currently have a position
    def get_available_funds(self):
        y = self.get_account()
        return y['securitiesAccount']['currentBalances']['availableFunds']

    def get_has_position(self):
        y = self.get_account()
        
        if "positions" in y["securitiesAccount"]:
            return True
        else:
            return False

    def get_positions(self):
        y = self.get_account()

        if "positions" in y["securitiesAccount"]:
            return y["securitiesAccount"]["positions"]
        else:
            return []
        

    def place_order(self, order_type, shares):

        if order_type == 'buy':
            order_spec = equity_buy_market(self.SYMBOL, shares).set_session(
                Session.NORMAL).set_duration(Duration.DAY).build()
            self.c.place_order(self.ACCOUNT_NUMBER, order_spec)

        if order_type == 'sell':
            order_spec = equity_sell_market(self.SYMBOL, shares).set_session(
                Session.NORMAL).set_duration(Duration.DAY).build()
            self.c.place_order(self.ACCOUNT_NUMBER, order_spec)

    def get_transactions(self):
        r = self.c.get_transactions(self.ACCOUNT_NUMBER)
        assert r.status_code == 200, r.raise_for_status()

        y = r.json()
        
        return y

# %%
td_ameritrade = TDAmeritrade(ACCT_NUMBER, API_KEY, CALLBACK_URL, ticker)

current_date = datetime.today()
past_date = current_date - relativedelta(years=2)
#df = pd.read_csv('.\\Data\\' + ticker + '.csv')
df = td_ameritrade.get_daily_price_history(ticker, past_date, current_date)

df.rename(columns = {'datetime':'Date', 'open':'Open', 'high':'High', 'low':'Low', 'close':'Close', 'volume':'Volume'}, inplace = True)
testing = df.copy()

if TESTING == True:
    tot = len(df)
    test_count = int(tot * .1)
    train_count = int(tot * .9)
    df = df.head(train_count)
    testing = testing.tail(test_count)
    #display(df)
    #display(testing)

# %%
close = df.Close.values.tolist()
window_size = 30
skip = 1

avail_funds = td_ameritrade.get_available_funds()
print("Available Funds: "  + str(avail_funds))
model = Model(input_size = window_size, layer_size = 500, output_size = 3)
agent = Agent(model = model, 
              window_size = window_size,
              trend = close,
              skip = skip,
              initial_money = avail_funds)
agent.fit(iterations = 200, checkpoint = 2)
# Out:
# Available Funds: 380.71
# iter 2. reward: -30.242179
# iter 4. reward: -25.254787
# time taken to train: 22.527477979660034 seconds

# %%
def trade_if_ai_says_to():
    print('trade_if_ai_says_to')

    last_dt = df.iloc[-1]['Date']
    #last_dt = datetime.strptime(date_string, '%Y-%m-%d')
    now = datetime.now()
    countdown = now - last_dt
    days_since_training_the_model = countdown.days

    inventory = td_ameritrade.get_positions()
    cur_price = td_ameritrade.get_cur_price()
    
    print("Price: " + str(cur_price) + " Day: " + str(days_since_training_the_model))
    inventory, buy, sell, tg, invest = agent.buy(inventory, cur_price, days_since_training_the_model)

def test_trade_if_ai_says_to(index, inventory):
    last_dt = df.iloc[-1]['Date']
    now_dt = testing.iloc[index]['Date']
    countdown = now_dt - last_dt
    days_since_training_the_model = countdown.days

    cur_price = testing.iloc[index]['Open']
    
    print("Price: " + str(cur_price) + " Day: " + str(days_since_training_the_model))
    inventory, buy, sell, tg, invest = agent.buy(inventory, cur_price, days_since_training_the_model)

    return inventory

# %%
# TODO: Update Historical prices every-day?
# TODO: Retrain Every day?
# TODO: Figure out if the market is open

if TESTING == False:
    schedule.every().monday.at('07:30').do(trade_if_ai_says_to)
    schedule.every().tuesday.at('07:30').do(trade_if_ai_says_to)
    schedule.every().wednesday.at('07:30').do(trade_if_ai_says_to)
    schedule.every().thursday.at('07:30').do(trade_if_ai_says_to)
    schedule.every().friday.at('07:30').do(trade_if_ai_says_to)

    while True:
       schedule.run_pending()
       time.sleep(1)

elif TESTING == True:
    inventory = []
    rg = len(testing)
    for i in range(0, rg - 1):
        inventory = test_trade_if_ai_says_to(i, inventory)
        #print(initial_money)
        
price = td_ameritrade.get_cur_price()
value = price * len(inventory)
print('Invetory: ' + str(len(inventory)))
print('Current of Inventory: ' + str(value))
# Out:
# Price: 25.75 Day: 5
# starting_money 380.71
# self.initial_money 354.96
# current_price 25.75
# buy 1 unit at price 25.750000, total balance 354.960000
# Price: 24.73 Day: 6
# starting_money 354.96
# self.initial_money 330.22999999999996
# current_price 24.73
# buy 1 unit at price 24.730000, total balance 330.230000
# Price: 25.0 Day: 7
# starting_money 330.22999999999996
# self.initial_money 305.22999999999996
# current_price 25.0
# buy 1 unit at price 25.000000, total balance 305.230000
# Price: 26.3 Day: 8
# starting_money 305.22999999999996
# self.initial_money 278.92999999999995
# current_price 26.3
# buy 1 unit at price 26.300000, total balance 278.930000
# Price: 29.03 Day: 11
# starting_money 278.92999999999995
# self.initial_money 249.89999999999995
# current_price 29.03
# buy 1 unit at price 29.030000, total balance 249.900000
# Price: 27.4 Day: 12
# starting_money 249.89999999999995
# self.initial_money 222.49999999999994
# current_price 27.4
# buy 1 unit at price 27.400000, total balance 222.500000
# Price: 27.56 Day: 13
# starting_money 222.49999999999994
# self.initial_money 194.93999999999994
# current_price 27.56
# buy 1 unit at price 27.560000, total balance 194.940000
# Price: 27.86 Day: 14
# starting_money 194.93999999999994
# self.initial_money 167.07999999999993
# current_price 27.86
# buy 1 unit at price 27.860000, total balance 167.080000
# Price: 28.33 Day: 15
# starting_money 167.07999999999993
# self.initial_money 138.74999999999994
# current_price 28.33
# buy 1 unit at price 28.330000, total balance 138.750000
# Price: 28.335 Day: 18
# starting_money 138.74999999999994
# self.initial_money 110.41499999999994
# current_price 28.335
# buy 1 unit at price 28.335000, total balance 110.415000
# Price: 29.28 Day: 19
# starting_money 110.41499999999994
# self.initial_money 81.13499999999993
# current_price 29.28
# buy 1 unit at price 29.280000, total balance 81.135000
# Price: 27.45 Day: 20
# starting_money 81.13499999999993
# self.initial_money 53.68499999999993
# current_price 27.45
# buy 1 unit at price 27.450000, total balance 53.685000
# Price: 27.17 Day: 21
# starting_money 53.68499999999993
# self.initial_money 26.51499999999993
# current_price 27.17
# buy 1 unit at price 27.170000, total balance 26.515000
# Price: 24.15 Day: 22
# starting_money 26.51499999999993
# self.initial_money 2.364999999999931
# current_price 24.15
# buy 1 unit at price 24.150000, total balance 2.365000
# Price: 24.66 Day: 25
# Price: 25.47 Day: 26
# sell 1 unit at price 25.470000, investment -1.087379 %, total balance 27.835000,
# Price: 25.89 Day: 27
# starting_money 27.83499999999993
# self.initial_money 1.9449999999999292
# current_price 25.89
# buy 1 unit at price 25.890000, total balance 1.945000
# Price: 27.08 Day: 28
# Price: 25.03 Day: 29
# sell 1 unit at price 25.030000, investment 1.213101 %, total balance 26.975000,
# Price: 25.14 Day: 32
# starting_money 26.97499999999993
# self.initial_money 1.8349999999999298
# current_price 25.14
# buy 1 unit at price 25.140000, total balance 1.835000
# Price: 25.95 Day: 33
# Price: 26.77 Day: 34
# Price: 26.29 Day: 35
# Price: 25.84 Day: 36
# Price: 25.37 Day: 39
# Price: 24.87 Day: 40
# Price: 25.96 Day: 41
# Price: 24.42 Day: 42
# Price: 25.77 Day: 43
# sell 1 unit at price 25.770000, investment 3.080000 %, total balance 27.605000,
# Price: 25.37 Day: 46
# starting_money 27.60499999999993
# self.initial_money 2.2349999999999284
# current_price 25.37
# buy 1 unit at price 25.370000, total balance 2.235000
# Price: 27.1 Day: 47
# Price: 26.0 Day: 48
# Price: 24.65 Day: 49
# Price: 24.15 Day: 50
# Price: 25.0 Day: 53
# Price: 24.815 Day: 54
# sell 1 unit at price 24.815000, investment -5.646388 %, total balance 27.050000,
# Price: 26.37 Day: 55
# Price: 25.75 Day: 56
# Price: 26.88 Day: 57
# starting_money 27.04999999999993
# self.initial_money 0.16999999999993065
# current_price 26.88
# buy 1 unit at price 26.880000, total balance 0.170000
# Price: 31.22 Day: 60
# Price: 29.4 Day: 61
# Price: 27.9 Day: 62
# sell 1 unit at price 27.900000, investment -3.892525 %, total balance 28.070000,
# Price: 26.0 Day: 63
# sell 1 unit at price 26.000000, investment -5.109489 %, total balance 54.070000,
# Price: 26.6 Day: 64
# starting_money 54.06999999999993
# self.initial_money 27.469999999999928
# current_price 26.6
# buy 1 unit at price 26.600000, total balance 27.470000
# Price: 26.25 Day: 67
# sell 1 unit at price 26.250000, investment -4.753266 %, total balance 53.720000,
# Price: 25.33 Day: 68
# sell 1 unit at price 25.330000, investment -9.081120 %, total balance 79.050000,
# Price: 24.55 Day: 69
# sell 1 unit at price 24.550000, investment -13.342746 %, total balance 103.600000,
# Price: 24.62 Day: 70
# sell 1 unit at price 24.620000, investment -13.110993 %, total balance 128.220000,
# Price: 24.78 Day: 71
# Invetory: 9
# Current of Inventory: 238.41

# %%
#fig = plt.figure(figsize = (15,5))
#plt.plot(close, color='r', lw=2.)
#plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
#plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
#plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
#plt.legend()
#plt.show()
