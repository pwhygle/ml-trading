# %%
import numpy as np
import pandas as pd
import time
import matplotlib.pyplot as plt
import seaborn as sns
import random
sns.set()

# %%
import pkg_resources
import types

def get_imports():
    for name, val in globals().items():
        if isinstance(val, types.ModuleType):
            name = val.__name__.split('.')[0]
        elif isinstance(val, type):
            name = val.__module__.split('.')[0]
        poorly_named_packages = {'PIL': 'Pillow', 'sklearn': 'scikit-learn'}
        if name in poorly_named_packages.keys():
            name = poorly_named_packages[name]
        yield name


imports = list(set(get_imports()))
requirements = []
for m in pkg_resources.working_set:
    if m.project_name in imports and m.project_name != 'pip':
        requirements.append((m.project_name, m.version))

for r in requirements:
    print('{}=={}'.format(*r))
# Out:
# numpy==1.23.4
# matplotlib==3.6.2
# pandas==1.5.1
# seaborn==0.12.1

# %%
df = pd.read_csv('.\\Data\\AMC.csv')
df.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close   Volume
# 0  2013-12-18  19.180000  19.790001  18.900000  18.900000  13.593410  5457200
# 1  2013-12-19  18.900000  19.490000  18.809999  19.490000  14.017756  1605400
# 2  2013-12-20  19.650000  19.770000  19.400000  19.680000  14.154412   737100
# 3  2013-12-23  19.790001  19.990000  19.500000  19.740000  14.197567   698100
# 4  2013-12-24  19.740000  19.820000  19.500000  19.530001  14.046524   213700

# %%
class Deep_Evolution_Strategy:

    inputs = None

    def __init__(
        self, weights, reward_function, population_size, sigma, learning_rate
    ):
        self.weights = weights
        self.reward_function = reward_function
        self.population_size = population_size
        self.sigma = sigma
        self.learning_rate = learning_rate

    def _get_weight_from_population(self, weights, population):
        weights_population = []
        for index, i in enumerate(population):
            jittered = self.sigma * i
            weights_population.append(weights[index] + jittered)
        return weights_population

    def get_weights(self):
        return self.weights

    def train(self, epoch = 100, print_every = 1):
        lasttime = time.time()
        for i in range(epoch):
            population = []
            rewards = np.zeros(self.population_size)
            for k in range(self.population_size):
                x = []
                for w in self.weights:
                    x.append(np.random.randn(*w.shape))
                population.append(x)
            for k in range(self.population_size):
                weights_population = self._get_weight_from_population(
                    self.weights, population[k]
                )
                rewards[k] = self.reward_function(weights_population)
            rewards = (rewards - np.mean(rewards)) / (np.std(rewards) + 1e-7)
            for index, w in enumerate(self.weights):
                A = np.array([p[index] for p in population])
                self.weights[index] = (
                    w
                    + self.learning_rate
                    / (self.population_size * self.sigma)
                    * np.dot(A.T, rewards).T
                )
            if (i + 1) % print_every == 0:
                print(
                    'iter %d. reward: %f'
                    % (i + 1, self.reward_function(self.weights))
                )
        print('time taken to train:', time.time() - lasttime, 'seconds')


class Model:
    def __init__(self, input_size, layer_size, output_size):
        self.weights = [
            np.random.randn(input_size, layer_size),
            np.random.randn(layer_size, output_size),
            np.random.randn(1, layer_size),
        ]

    def predict(self, inputs):
        feed = np.dot(inputs, self.weights[0]) + self.weights[-1]
        decision = np.dot(feed, self.weights[1])
        return decision

    def get_weights(self):
        return self.weights

    def set_weights(self, weights):
        self.weights = weights

# %%
class Agent:

    POPULATION_SIZE = 15
    SIGMA = 0.1
    LEARNING_RATE = 0.03

    def __init__(self, model, window_size, trend, skip, initial_money):
        self.model = model
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        self.initial_money = initial_money
        self.es = Deep_Evolution_Strategy(
            self.model.get_weights(),
            self.get_reward,
            self.POPULATION_SIZE,
            self.SIGMA,
            self.LEARNING_RATE,
        )

    def act(self, sequence):
        decision = self.model.predict(np.array(sequence))
        return np.argmax(decision[0])
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array([res])

    def get_reward(self, weights):
        initial_money = self.initial_money
        starting_money = initial_money
        self.model.weights = weights
        state = self.get_state(0)
        inventory = []
        quantity = 0
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and starting_money >= self.trend[t]:
                inventory.append(self.trend[t])
                starting_money -= close[t]
                
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                starting_money += self.trend[t]

            state = next_state
        return ((starting_money - initial_money) / initial_money) * 100

    def fit(self, iterations, checkpoint):
        self.es.train(iterations, print_every = checkpoint)

    def buy(self):
        initial_money = self.initial_money
        state = self.get_state(0)
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            state = next_state

        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest

# %%
close = df.Close.values.tolist()
window_size = 30
skip = 1
initial_money = 2000

model = Model(input_size = window_size, layer_size = 500, output_size = 3)
agent = Agent(model = model, 
              window_size = window_size,
              trend = close,
              skip = skip,
              initial_money = initial_money)
agent.fit(iterations = 500, checkpoint = 10)
# Out:
# iter 10. reward: -3.681501
# iter 20. reward: 5.236999
# iter 30. reward: 5.684499
# iter 40. reward: 6.311499
# iter 50. reward: 10.248499
# iter 60. reward: 29.076999
# iter 70. reward: 30.198499
# iter 80. reward: 62.112499
# iter 90. reward: 47.571000
# iter 100. reward: 61.982999
# iter 110. reward: 55.262998
# iter 120. reward: 58.356999
# iter 130. reward: 73.055999
# iter 140. reward: 66.841998
# iter 150. reward: 24.459998
# iter 160. reward: 44.834999
# iter 170. reward: 73.269498
# iter 180. reward: 92.032499
# iter 190. reward: 94.287499
# iter 200. reward: 97.807999
# iter 210. reward: 76.099999
# iter 220. reward: 101.690499
# iter 230. reward: 91.217500
# iter 240. reward: 73.436499
# iter 250. reward: 66.012501
# iter 260. reward: 61.108501
# iter 270. reward: 95.307000
# iter 280. reward: 91.094000
# iter 290. reward: 48.626501
# iter 300. reward: 84.050500
# iter 310. reward: 98.337000
# iter 320. reward: 97.681000
# iter 330. reward: 112.467500
# iter 340. reward: 117.018000
# iter 350. reward: 125.998501
# iter 360. reward: 93.880499
# iter 370. reward: 77.465498
# iter 380. reward: 93.202500
# iter 390. reward: 77.372500
# iter 400. reward: 130.434501
# iter 410. reward: 137.153501
# iter 420. reward: 121.483000
# iter 430. reward: 131.619502
# iter 440. reward: 112.996000
# iter 450. reward: 94.220500
# iter 460. reward: 94.889500
# iter 470. reward: 120.859000
# iter 480. reward: 128.779001
# iter 490. reward: 137.076000
# iter 500. reward: 121.934001
# time taken to train: 2088.204926967621 seconds

# %%
states_buy, states_sell, total_gains, invest = agent.buy()
# Out:
# day 0: buy 1 unit at price 18.900000, total balance 1981.100000
# day 1: buy 1 unit at price 19.490000, total balance 1961.610000
# day 2, sell 1 unit at price 19.680000, investment 4.126984 %, total balance 1981.290000,
# day 3: buy 1 unit at price 19.740000, total balance 1961.550000
# day 4, sell 1 unit at price 19.530001, investment 0.205239 %, total balance 1981.080001,
# day 5: buy 1 unit at price 19.780001, total balance 1961.300000
# day 6: buy 1 unit at price 20.139999, total balance 1941.160001
# day 7, sell 1 unit at price 19.980000, investment 1.215805 %, total balance 1961.140001,
# day 8, sell 1 unit at price 20.549999, investment 3.892811 %, total balance 1981.690000,
# day 9, sell 1 unit at price 20.180000, investment 0.198615 %, total balance 2001.870000,
# day 10: buy 1 unit at price 20.020000, total balance 1981.850000
# day 11, sell 1 unit at price 20.010000, investment -0.049950 %, total balance 2001.860000,
# day 13: buy 1 unit at price 19.959999, total balance 1981.900001
# day 14, sell 1 unit at price 20.030001, investment 0.350711 %, total balance 2001.930002,
# day 15: buy 1 unit at price 20.040001, total balance 1981.890001
# day 16, sell 1 unit at price 19.980000, investment -0.299406 %, total balance 2001.870001,
# day 17: buy 1 unit at price 20.120001, total balance 1981.750000
# day 18: buy 1 unit at price 19.990000, total balance 1961.760000
# day 19, sell 1 unit at price 20.299999, investment 0.894622 %, total balance 1982.059999,
# day 20: buy 1 unit at price 20.240000, total balance 1961.819999
# day 21, sell 1 unit at price 20.850000, investment 4.302151 %, total balance 1982.669999,
# day 22, sell 1 unit at price 21.260000, investment 5.039526 %, total balance 2003.929999,
# day 24: buy 1 unit at price 21.370001, total balance 1982.559998
# day 25: buy 1 unit at price 21.350000, total balance 1961.209998
# day 26, sell 1 unit at price 21.910000, investment 2.526902 %, total balance 1983.119998,
# day 27, sell 1 unit at price 21.639999, investment 1.358309 %, total balance 2004.759997,
# day 28: buy 1 unit at price 21.530001, total balance 1983.229996
# day 29, sell 1 unit at price 21.370001, investment -0.743149 %, total balance 2004.599997,
# day 31: buy 1 unit at price 21.020000, total balance 1983.579997
# day 32, sell 1 unit at price 21.040001, investment 0.095152 %, total balance 2004.619998,
# day 33: buy 1 unit at price 21.160000, total balance 1983.459998
# day 34, sell 1 unit at price 21.320000, investment 0.756144 %, total balance 2004.779998,
# day 35: buy 1 unit at price 21.370001, total balance 1983.409997
# day 36: buy 1 unit at price 21.770000, total balance 1961.639997
# day 37, sell 1 unit at price 22.040001, investment 3.135236 %, total balance 1983.679998,
# day 38: buy 1 unit at price 22.100000, total balance 1961.579998
# day 39, sell 1 unit at price 22.000000, investment 1.056500 %, total balance 1983.579998,
# day 41: buy 1 unit at price 21.930000, total balance 1961.649998
# day 42, sell 1 unit at price 21.950001, investment -0.678729 %, total balance 1983.599999,
# day 43: buy 1 unit at price 22.309999, total balance 1961.290000
# day 44, sell 1 unit at price 22.389999, investment 2.097579 %, total balance 1983.679999,
# day 45: buy 1 unit at price 22.469999, total balance 1961.210000
# day 46, sell 1 unit at price 22.520000, investment 0.941286 %, total balance 1983.730000,
# day 47, sell 1 unit at price 22.740000, investment 1.201607 %, total balance 2006.470000,
# day 48: buy 1 unit at price 22.889999, total balance 1983.580001
# day 49: buy 1 unit at price 22.950001, total balance 1960.630000
# day 50, sell 1 unit at price 23.980000, investment 4.761909 %, total balance 1984.610000,
# day 51, sell 1 unit at price 24.660000, investment 7.450976 %, total balance 2009.270000,
# day 55: buy 1 unit at price 23.980000, total balance 1985.290000
# day 56: buy 1 unit at price 23.290001, total balance 1961.999999
# day 57: buy 1 unit at price 23.870001, total balance 1938.129998
# day 58, sell 1 unit at price 24.110001, investment 0.542123 %, total balance 1962.239999,
# day 59: buy 1 unit at price 25.059999, total balance 1937.180000
# day 60, sell 1 unit at price 24.400000, investment 4.765989 %, total balance 1961.580000,
# day 61, sell 1 unit at price 23.580000, investment -1.214918 %, total balance 1985.160000,
# day 62: buy 1 unit at price 23.510000, total balance 1961.650000
# day 63: buy 1 unit at price 23.059999, total balance 1938.590001
# day 64: buy 1 unit at price 23.180000, total balance 1915.410001
# day 65, sell 1 unit at price 24.010000, investment -4.189940 %, total balance 1939.420001,
# day 67, sell 1 unit at price 23.420000, investment -0.382816 %, total balance 1962.840001,
# day 68, sell 1 unit at price 23.900000, investment 3.642676 %, total balance 1986.740001,
# day 69: buy 1 unit at price 24.250000, total balance 1962.490001
# day 70, sell 1 unit at price 24.719999, investment 6.643654 %, total balance 1987.210000,
# day 72, sell 1 unit at price 23.480000, investment -3.175258 %, total balance 2010.690000,
# day 73: buy 1 unit at price 23.020000, total balance 1987.670000
# day 74: buy 1 unit at price 23.020000, total balance 1964.650000
# day 75, sell 1 unit at price 23.969999, investment 4.126842 %, total balance 1988.619999,
# day 76, sell 1 unit at price 23.639999, investment 2.693306 %, total balance 2012.259998,
# day 79: buy 1 unit at price 23.590000, total balance 1988.669998
# day 80: buy 1 unit at price 22.410000, total balance 1966.259998
# day 81: buy 1 unit at price 22.510000, total balance 1943.749998
# day 84, sell 1 unit at price 22.790001, investment -3.391263 %, total balance 1966.539999,
# day 85: buy 1 unit at price 22.870001, total balance 1943.669998
# day 86, sell 1 unit at price 23.379999, investment 4.328420 %, total balance 1967.049997,
# day 88: buy 1 unit at price 22.590000, total balance 1944.459997
# day 89, sell 1 unit at price 22.480000, investment -0.133274 %, total balance 1966.939997,
# day 91, sell 1 unit at price 24.000000, investment 4.940966 %, total balance 1990.939997,
# day 92: buy 1 unit at price 23.740000, total balance 1967.199997
# day 93, sell 1 unit at price 22.889999, investment 1.328017 %, total balance 1990.089996,
# day 94, sell 1 unit at price 22.200001, investment -6.486938 %, total balance 2012.289997,
# day 98: buy 1 unit at price 21.610001, total balance 1990.679996
# day 99, sell 1 unit at price 21.660000, investment 0.231370 %, total balance 2012.339996,
# day 100: buy 1 unit at price 21.430000, total balance 1990.909996
# day 101, sell 1 unit at price 21.459999, investment 0.139986 %, total balance 2012.369995,
# day 103: buy 1 unit at price 21.959999, total balance 1990.409996
# day 104: buy 1 unit at price 21.959999, total balance 1968.449997
# day 105: buy 1 unit at price 22.080000, total balance 1946.369997
# day 106, sell 1 unit at price 22.389999, investment 1.958106 %, total balance 1968.759996,
# day 108, sell 1 unit at price 23.200001, investment 5.646640 %, total balance 1991.959997,
# day 109, sell 1 unit at price 23.000000, investment 4.166667 %, total balance 2014.959997,
# day 111: buy 1 unit at price 22.670000, total balance 1992.289997
# day 112: buy 1 unit at price 22.610001, total balance 1969.679996
# day 113: buy 1 unit at price 22.559999, total balance 1947.119997
# day 114: buy 1 unit at price 22.549999, total balance 1924.569998
# day 115, sell 1 unit at price 22.950001, investment 1.235117 %, total balance 1947.519999,
# day 116, sell 1 unit at price 24.000000, investment 6.147718 %, total balance 1971.519999,
# day 117, sell 1 unit at price 24.180000, investment 7.180856 %, total balance 1995.699999,
# day 118: buy 1 unit at price 24.190001, total balance 1971.509998
# day 119, sell 1 unit at price 24.120001, investment 6.962315 %, total balance 1995.629999,
# day 120: buy 1 unit at price 24.049999, total balance 1971.580000
# day 121: buy 1 unit at price 24.219999, total balance 1947.360001
# day 123, sell 1 unit at price 23.910000, investment -1.157507 %, total balance 1971.270001,
# day 124, sell 1 unit at price 24.400000, investment 1.455306 %, total balance 1995.670001,
# day 125: buy 1 unit at price 24.650000, total balance 1971.020001
# day 126, sell 1 unit at price 24.610001, investment 1.610248 %, total balance 1995.630002,
# day 127, sell 1 unit at price 24.170000, investment -1.947262 %, total balance 2019.800002,
# day 128: buy 1 unit at price 24.240000, total balance 1995.560002
# day 129: buy 1 unit at price 24.440001, total balance 1971.120001
# day 130: buy 1 unit at price 24.540001, total balance 1946.580000
# day 131: buy 1 unit at price 24.610001, total balance 1921.969999
# day 132, sell 1 unit at price 24.870001, investment 2.599014 %, total balance 1946.840000,
# day 133: buy 1 unit at price 24.469999, total balance 1922.370001
# day 134, sell 1 unit at price 24.750000, investment 1.268408 %, total balance 1947.120001,
# day 135, sell 1 unit at price 24.629999, investment 0.366740 %, total balance 1971.750000,
# day 136: buy 1 unit at price 24.070000, total balance 1947.680000
# day 137: buy 1 unit at price 23.590000, total balance 1924.090000
# day 138: buy 1 unit at price 23.650000, total balance 1900.440000
# day 139: buy 1 unit at price 23.340000, total balance 1877.100000
# day 140, sell 1 unit at price 23.280001, investment -5.404307 %, total balance 1900.380001,
# day 141: buy 1 unit at price 23.059999, total balance 1877.320002
# day 142, sell 1 unit at price 22.370001, investment -8.581929 %, total balance 1899.690003,
# day 143: buy 1 unit at price 22.290001, total balance 1877.400002
# day 144: buy 1 unit at price 22.459999, total balance 1854.940003
# day 145: buy 1 unit at price 22.530001, total balance 1832.410002
# day 146: buy 1 unit at price 22.650000, total balance 1809.760002
# day 147: buy 1 unit at price 22.840000, total balance 1786.920002
# day 148: buy 1 unit at price 22.600000, total balance 1764.320002
# day 149: buy 1 unit at price 22.600000, total balance 1741.720002
# day 150, sell 1 unit at price 23.010000, investment -4.403822 %, total balance 1764.730002,
# day 151: buy 1 unit at price 23.080000, total balance 1741.650002
# day 152: buy 1 unit at price 22.580000, total balance 1719.070002
# day 153: buy 1 unit at price 22.510000, total balance 1696.560002
# day 154, sell 1 unit at price 22.639999, investment -4.027134 %, total balance 1719.200001,
# day 155: buy 1 unit at price 23.000000, total balance 1696.200001
# day 156, sell 1 unit at price 23.360001, investment -1.226211 %, total balance 1719.560002,
# day 157: buy 1 unit at price 23.160000, total balance 1696.400002
# day 158, sell 1 unit at price 23.639999, investment 1.285343 %, total balance 1720.040001,
# day 159, sell 1 unit at price 23.549999, investment 2.124892 %, total balance 1743.590000,
# day 160: buy 1 unit at price 23.360001, total balance 1720.229999
# day 161, sell 1 unit at price 23.440001, investment 5.159264 %, total balance 1743.670000,
# day 162: buy 1 unit at price 23.240000, total balance 1720.430000
# day 163: buy 1 unit at price 23.090000, total balance 1697.340000
# day 164, sell 1 unit at price 22.740000, investment 1.246665 %, total balance 1720.080000,
# day 165, sell 1 unit at price 23.100000, investment 2.529956 %, total balance 1743.180000,
# day 166, sell 1 unit at price 23.430000, investment 3.443709 %, total balance 1766.610000,
# day 167: buy 1 unit at price 23.559999, total balance 1743.050001
# day 168: buy 1 unit at price 23.570000, total balance 1719.480001
# day 169, sell 1 unit at price 23.350000, investment 2.232925 %, total balance 1742.830001,
# day 171, sell 1 unit at price 23.570000, investment 4.292035 %, total balance 1766.400001,
# day 172: buy 1 unit at price 23.610001, total balance 1742.790000
# day 173, sell 1 unit at price 23.670000, investment 4.734513 %, total balance 1766.460000,
# day 174, sell 1 unit at price 23.639999, investment 2.426339 %, total balance 1790.099999,
# day 175: buy 1 unit at price 23.670000, total balance 1766.429999
# day 176, sell 1 unit at price 23.940001, investment 6.023034 %, total balance 1790.370000,
# day 177: buy 1 unit at price 24.010000, total balance 1766.360000
# day 178: buy 1 unit at price 24.219999, total balance 1742.140001
# day 179: buy 1 unit at price 24.450001, total balance 1717.690000
# day 180, sell 1 unit at price 24.799999, investment 10.173252 %, total balance 1742.489999,
# day 181, sell 1 unit at price 24.590000, investment 6.913043 %, total balance 1767.079999,
# day 182: buy 1 unit at price 24.530001, total balance 1742.549998
# day 183, sell 1 unit at price 24.610001, investment 6.260799 %, total balance 1767.159999,
# day 184, sell 1 unit at price 24.610001, investment 5.351027 %, total balance 1791.770000,
# day 185, sell 1 unit at price 24.600000, investment 5.851979 %, total balance 1816.370000,
# day 186, sell 1 unit at price 24.700001, investment 6.972720 %, total balance 1841.070001,
# day 187, sell 1 unit at price 24.790001, investment 5.220722 %, total balance 1865.860002,
# day 188: buy 1 unit at price 24.690001, total balance 1841.170001
# day 189: buy 1 unit at price 24.600000, total balance 1816.570001
# day 190, sell 1 unit at price 24.590000, investment 4.327535 %, total balance 1841.160001,
# day 191, sell 1 unit at price 23.770000, investment 0.677675 %, total balance 1864.930001,
# day 192: buy 1 unit at price 23.600000, total balance 1841.330001
# day 193: buy 1 unit at price 23.250000, total balance 1818.080001
# day 194: buy 1 unit at price 23.490000, total balance 1794.590001
# day 195: buy 1 unit at price 23.430000, total balance 1771.160001
# day 196: buy 1 unit at price 22.990000, total balance 1748.170001
# day 197: buy 1 unit at price 22.910000, total balance 1725.260001
# day 198: buy 1 unit at price 23.200001, total balance 1702.060000
# day 199: buy 1 unit at price 23.410000, total balance 1678.650000
# day 200, sell 1 unit at price 23.219999, investment -1.901145 %, total balance 1701.869999,
# day 201: buy 1 unit at price 22.469999, total balance 1679.400000
# day 202: buy 1 unit at price 22.620001, total balance 1656.779999
# day 203: buy 1 unit at price 22.299999, total balance 1634.480000
# day 204: buy 1 unit at price 21.760000, total balance 1612.720000
# day 205, sell 1 unit at price 21.370001, investment -10.995414 %, total balance 1634.090001,
# day 207: buy 1 unit at price 22.040001, total balance 1612.050000
# day 208, sell 1 unit at price 22.790001, investment -5.904203 %, total balance 1634.840001,
# day 209: buy 1 unit at price 22.200001, total balance 1612.640000
# day 210, sell 1 unit at price 22.260000, investment -8.957059 %, total balance 1634.900000,
# day 211: buy 1 unit at price 23.350000, total balance 1611.550000
# day 212: buy 1 unit at price 22.440001, total balance 1589.109999
# day 213, sell 1 unit at price 23.020000, investment -6.155732 %, total balance 1612.129999,
# day 214, sell 1 unit at price 23.420000, investment -5.143787 %, total balance 1635.549999,
# day 215: buy 1 unit at price 23.590000, total balance 1611.959999
# day 216, sell 1 unit at price 24.400000, investment -0.813008 %, total balance 1636.359999,
# day 217, sell 1 unit at price 25.160000, investment 6.610169 %, total balance 1661.519999,
# day 218, sell 1 unit at price 25.420000, investment 9.333333 %, total balance 1686.939999,
# day 219, sell 1 unit at price 25.400000, investment 8.131120 %, total balance 1712.339999,
# day 220: buy 1 unit at price 24.950001, total balance 1687.389998
# day 221, sell 1 unit at price 24.520000, investment 4.652155 %, total balance 1711.909998,
# day 223: buy 1 unit at price 25.090000, total balance 1686.819998
# day 224, sell 1 unit at price 25.719999, investment 11.874724 %, total balance 1712.539997,
# day 225: buy 1 unit at price 25.600000, total balance 1686.939997
# day 226, sell 1 unit at price 25.850000, investment 12.832824 %, total balance 1712.789997,
# day 227, sell 1 unit at price 25.820000, investment 11.293099 %, total balance 1738.609997,
# day 228: buy 1 unit at price 25.629999, total balance 1712.979998
# day 229, sell 1 unit at price 25.520000, investment 9.013242 %, total balance 1738.499998,
# day 231, sell 1 unit at price 25.709999, investment 14.419226 %, total balance 1764.209997,
# day 232, sell 1 unit at price 25.660000, investment 13.439429 %, total balance 1789.869997,
# day 233: buy 1 unit at price 25.639999, total balance 1764.229998
# day 234, sell 1 unit at price 25.030001, investment 12.242162 %, total balance 1789.259999,
# day 236: buy 1 unit at price 26.340000, total balance 1762.919999
# day 237, sell 1 unit at price 26.420000, investment 21.415441 %, total balance 1789.339999,
# day 238: buy 1 unit at price 26.219999, total balance 1763.120000
# day 239: buy 1 unit at price 26.430000, total balance 1736.690000
# day 240: buy 1 unit at price 26.090000, total balance 1710.600000
# day 241, sell 1 unit at price 25.450001, investment 15.471869 %, total balance 1736.050001,
# day 242, sell 1 unit at price 25.709999, investment 15.810801 %, total balance 1761.760000,
# day 243, sell 1 unit at price 25.250000, investment 8.137045 %, total balance 1787.010000,
# day 244: buy 1 unit at price 25.240000, total balance 1761.770000
# day 245: buy 1 unit at price 25.030001, total balance 1736.739999
# day 246: buy 1 unit at price 24.709999, total balance 1712.030000
# day 247: buy 1 unit at price 24.860001, total balance 1687.169999
# day 248: buy 1 unit at price 24.910000, total balance 1662.259999
# day 249: buy 1 unit at price 24.930000, total balance 1637.329999
# day 250, sell 1 unit at price 24.200001, investment 7.843137 %, total balance 1661.530000,
# day 252: buy 1 unit at price 25.910000, total balance 1635.620000
# day 253, sell 1 unit at price 26.170000, investment 10.936838 %, total balance 1661.790000,
# day 254: buy 1 unit at price 26.480000, total balance 1635.310000
# day 255, sell 1 unit at price 26.820000, investment 7.494986 %, total balance 1662.130000,
# day 256: buy 1 unit at price 26.620001, total balance 1635.509999
# day 257, sell 1 unit at price 26.389999, investment 5.181343 %, total balance 1661.899998,
# day 258: buy 1 unit at price 26.340000, total balance 1635.559998
# day 259, sell 1 unit at price 26.100000, investment 1.953125 %, total balance 1661.659998,
# day 260: buy 1 unit at price 26.180000, total balance 1635.479998
# day 261: buy 1 unit at price 25.629999, total balance 1609.849999
# day 262, sell 1 unit at price 24.969999, investment -2.575107 %, total balance 1634.819998,
# day 263: buy 1 unit at price 25.170000, total balance 1609.649998
# day 264: buy 1 unit at price 25.580000, total balance 1584.069998
# day 265: buy 1 unit at price 25.830000, total balance 1558.239998
# day 266, sell 1 unit at price 26.870001, investment 4.797200 %, total balance 1585.109999,
# day 267, sell 1 unit at price 27.490000, investment 4.365983 %, total balance 1612.599999,
# day 268: buy 1 unit at price 27.360001, total balance 1585.239998
# day 269, sell 1 unit at price 27.440001, investment 4.652944 %, total balance 1612.679999,
# day 270: buy 1 unit at price 27.290001, total balance 1585.389998
# day 273, sell 1 unit at price 27.139999, investment 2.686337 %, total balance 1612.529997,
# day 274, sell 1 unit at price 27.770000, investment 6.439249 %, total balance 1640.299997,
# day 275: buy 1 unit at price 28.299999, total balance 1611.999998
# day 276, sell 1 unit at price 28.469999, investment 12.797143 %, total balance 1640.469997,
# day 277, sell 1 unit at price 28.480000, investment 13.783455 %, total balance 1668.949997,
# day 278, sell 1 unit at price 27.590000, investment 11.655205 %, total balance 1696.539997,
# day 279: buy 1 unit at price 28.250000, total balance 1668.289997
# day 280, sell 1 unit at price 28.120001, investment 13.113435 %, total balance 1696.409998,
# day 281, sell 1 unit at price 28.280001, investment 13.528707 %, total balance 1724.689999,
# day 282, sell 1 unit at price 29.010000, investment 16.365824 %, total balance 1753.699999,
# day 284, sell 1 unit at price 29.430000, investment 13.585488 %, total balance 1783.129999,
# day 285, sell 1 unit at price 29.420000, investment 11.102719 %, total balance 1812.549999,
# day 286: buy 1 unit at price 29.980000, total balance 1782.569999
# day 287, sell 1 unit at price 30.180000, investment 13.373399 %, total balance 1812.749999,
# day 288: buy 1 unit at price 30.290001, total balance 1782.459998
# day 289: buy 1 unit at price 30.389999, total balance 1752.069999
# day 290, sell 1 unit at price 30.620001, investment 16.249055 %, total balance 1782.690000,
# day 291: buy 1 unit at price 30.900000, total balance 1751.790000
# day 292, sell 1 unit at price 31.520000, investment 20.397250 %, total balance 1783.310000,
# day 293, sell 1 unit at price 32.480000, investment 26.726497 %, total balance 1815.790000,
# day 294, sell 1 unit at price 32.610001, investment 29.559003 %, total balance 1848.400001,
# day 295, sell 1 unit at price 32.689999, investment 27.795149 %, total balance 1881.090000,
# day 296: buy 1 unit at price 32.939999, total balance 1848.150001
# day 297, sell 1 unit at price 32.980000, investment 27.680991 %, total balance 1881.130001,
# day 298: buy 1 unit at price 33.630001, total balance 1847.500000
# day 299, sell 1 unit at price 34.380001, investment 25.657894 %, total balance 1881.880001,
# day 300, sell 1 unit at price 35.240002, investment 29.131553 %, total balance 1917.120003,
# day 301, sell 1 unit at price 34.860001, investment 23.180220 %, total balance 1951.980004,
# day 302: buy 1 unit at price 35.049999, total balance 1916.930005
# day 303, sell 1 unit at price 34.869999, investment 23.433625 %, total balance 1951.800004,
# day 304, sell 1 unit at price 33.959999, investment 13.275514 %, total balance 1985.760003,
# day 305: buy 1 unit at price 34.880001, total balance 1950.880002
# day 306, sell 1 unit at price 33.799999, investment 11.587976 %, total balance 1984.680001,
# day 308, sell 1 unit at price 34.320000, investment 12.931889 %, total balance 2019.000001,
# day 309: buy 1 unit at price 34.900002, total balance 1984.099999
# day 310, sell 1 unit at price 35.160000, investment 13.786408 %, total balance 2019.259999,
# day 311, sell 1 unit at price 35.139999, investment 6.678810 %, total balance 2054.399998,
# day 312: buy 1 unit at price 35.320000, total balance 2019.079998
# day 313, sell 1 unit at price 35.450001, investment 5.411835 %, total balance 2054.529999,
# day 314: buy 1 unit at price 35.680000, total balance 2018.849999
# day 315, sell 1 unit at price 35.860001, investment 2.310990 %, total balance 2054.710000,
# day 316: buy 1 unit at price 34.950001, total balance 2019.759999
# day 317: buy 1 unit at price 34.509998, total balance 1985.250001
# day 318, sell 1 unit at price 34.630001, investment -0.716743 %, total balance 2019.880002,
# day 320, sell 1 unit at price 35.520000, investment 1.776498 %, total balance 2055.400002,
# day 321: buy 1 unit at price 35.490002, total balance 2019.910000
# day 322: buy 1 unit at price 34.759998, total balance 1985.150002
# day 323, sell 1 unit at price 35.180000, investment -0.396376 %, total balance 2020.330002,
# day 324: buy 1 unit at price 35.380001, total balance 1984.950001
# day 325, sell 1 unit at price 34.709999, investment -2.718613 %, total balance 2019.660000,
# day 326: buy 1 unit at price 35.200001, total balance 1984.459999
# day 327, sell 1 unit at price 34.250000, investment -2.002864 %, total balance 2018.709999,
# day 329, sell 1 unit at price 33.439999, investment -3.100548 %, total balance 2052.149998,
# day 330: buy 1 unit at price 33.689999, total balance 2018.459999
# day 331, sell 1 unit at price 33.910000, investment -4.451964 %, total balance 2052.369999,
# day 333: buy 1 unit at price 32.799999, total balance 2019.570000
# day 334, sell 1 unit at price 33.689999, investment -3.078248 %, total balance 2053.259999,
# day 335: buy 1 unit at price 33.369999, total balance 2019.890000
# day 336: buy 1 unit at price 32.900002, total balance 1986.989998
# day 337: buy 1 unit at price 32.970001, total balance 1954.019997
# day 339, sell 1 unit at price 32.040001, investment -9.440362 %, total balance 1986.059998,
# day 341, sell 1 unit at price 32.500000, investment -7.670457 %, total balance 2018.559998,
# day 344, sell 1 unit at price 30.490000, investment -9.498365 %, total balance 2049.049998,
# day 346: buy 1 unit at price 29.540001, total balance 2019.509997
# day 347: buy 1 unit at price 29.830000, total balance 1989.679997
# day 348, sell 1 unit at price 29.660000, investment -9.573168 %, total balance 2019.339997,
# day 350: buy 1 unit at price 29.010000, total balance 1990.329997
# day 351, sell 1 unit at price 29.389999, investment -11.926881 %, total balance 2019.719996,
# day 354, sell 1 unit at price 29.900000, investment -9.118547 %, total balance 2049.619996,
# day 355, sell 1 unit at price 29.400000, investment -10.828028 %, total balance 2079.019996,
# day 356: buy 1 unit at price 29.459999, total balance 2049.559997
# day 358: buy 1 unit at price 29.600000, total balance 2019.959997
# day 359, sell 1 unit at price 29.520000, investment -0.067708 %, total balance 2049.479997,
# day 361, sell 1 unit at price 29.250000, investment -1.944351 %, total balance 2078.729997,
# day 362, sell 1 unit at price 28.910000, investment -0.344709 %, total balance 2107.639997,
# day 364: buy 1 unit at price 27.870001, total balance 2079.769996
# day 365, sell 1 unit at price 28.440001, investment -3.462315 %, total balance 2108.209997,
# day 366: buy 1 unit at price 28.240000, total balance 2079.969997
# day 367, sell 1 unit at price 28.830000, investment -2.601351 %, total balance 2108.799997,
# day 369, sell 1 unit at price 28.510000, investment 2.296372 %, total balance 2137.309997,
# day 372, sell 1 unit at price 28.469999, investment 0.814444 %, total balance 2165.779996,
# day 374: buy 1 unit at price 28.469999, total balance 2137.309997
# day 375, sell 1 unit at price 28.010000, investment -1.615732 %, total balance 2165.319997,
# day 376: buy 1 unit at price 29.580000, total balance 2135.739997
# day 377: buy 1 unit at price 30.100000, total balance 2105.639997
# day 378, sell 1 unit at price 30.549999, investment 3.279239 %, total balance 2136.189996,
# day 379, sell 1 unit at price 30.420000, investment 1.063123 %, total balance 2166.609996,
# day 381: buy 1 unit at price 30.280001, total balance 2136.329995
# day 382: buy 1 unit at price 31.639999, total balance 2104.689996
# day 383, sell 1 unit at price 30.440001, investment 0.528402 %, total balance 2135.129997,
# day 384, sell 1 unit at price 30.680000, investment -3.034131 %, total balance 2165.809997,
# day 388: buy 1 unit at price 30.850000, total balance 2134.959997
# day 389, sell 1 unit at price 30.469999, investment -1.231770 %, total balance 2165.429996,
# day 391: buy 1 unit at price 31.350000, total balance 2134.079996
# day 392, sell 1 unit at price 31.840000, investment 1.562998 %, total balance 2165.919996,
# day 393: buy 1 unit at price 32.639999, total balance 2133.279997
# day 394, sell 1 unit at price 32.500000, investment -0.428919 %, total balance 2165.779997,
# day 399: buy 1 unit at price 32.330002, total balance 2133.449995
# day 400, sell 1 unit at price 32.209999, investment -0.371182 %, total balance 2165.659994,
# day 401: buy 1 unit at price 31.049999, total balance 2134.609995
# day 402, sell 1 unit at price 30.750000, investment -0.966180 %, total balance 2165.359995,
# day 404: buy 1 unit at price 30.430000, total balance 2134.929995
# day 405: buy 1 unit at price 31.690001, total balance 2103.239994
# day 406, sell 1 unit at price 32.250000, investment 5.980940 %, total balance 2135.489994,
# day 407, sell 1 unit at price 32.169998, investment 1.514664 %, total balance 2167.659992,
# day 408: buy 1 unit at price 31.590000, total balance 2136.069992
# day 409: buy 1 unit at price 30.559999, total balance 2105.509993
# day 414: buy 1 unit at price 28.360001, total balance 2077.149992
# day 415, sell 1 unit at price 29.070000, investment -7.977208 %, total balance 2106.219992,
# day 416: buy 1 unit at price 29.459999, total balance 2076.759993
# day 417: buy 1 unit at price 30.760000, total balance 2045.999993
# day 418, sell 1 unit at price 30.590000, investment 0.098171 %, total balance 2076.589993,
# day 419: buy 1 unit at price 31.000000, total balance 2045.589993
# day 420, sell 1 unit at price 29.799999, investment 5.077567 %, total balance 2075.389992,
# day 421: buy 1 unit at price 29.270000, total balance 2046.119992
# day 422, sell 1 unit at price 28.000000, investment -4.955869 %, total balance 2074.119992,
# day 425, sell 1 unit at price 28.860001, investment -6.176850 %, total balance 2102.979993,
# day 426: buy 1 unit at price 29.010000, total balance 2073.969993
# day 427: buy 1 unit at price 28.980000, total balance 2044.989993
# day 428: buy 1 unit at price 27.709999, total balance 2017.279994
# day 429: buy 1 unit at price 27.900000, total balance 1989.379994
# day 430, sell 1 unit at price 27.430000, investment -11.516129 %, total balance 2016.809994,
# day 432, sell 1 unit at price 27.910000, investment -4.646396 %, total balance 2044.719994,
# day 433, sell 1 unit at price 27.160000, investment -6.377111 %, total balance 2071.879994,
# day 434: buy 1 unit at price 27.129999, total balance 2044.749995
# day 437, sell 1 unit at price 27.120001, investment -6.418216 %, total balance 2071.869996,
# day 439: buy 1 unit at price 27.610001, total balance 2044.259995
# day 440: buy 1 unit at price 27.990000, total balance 2016.269995
# day 441, sell 1 unit at price 27.190001, investment -1.876572 %, total balance 2043.459996,
# day 442, sell 1 unit at price 25.870001, investment -7.275982 %, total balance 2069.329997,
# day 444: buy 1 unit at price 25.620001, total balance 2043.709996
# day 445, sell 1 unit at price 25.490000, investment -6.044965 %, total balance 2069.199996,
# day 446: buy 1 unit at price 24.459999, total balance 2044.739997
# day 447, sell 1 unit at price 24.270000, investment -12.097069 %, total balance 2069.009997,
# day 449: buy 1 unit at price 24.889999, total balance 2044.119998
# day 450, sell 1 unit at price 25.209999, investment -9.932122 %, total balance 2069.329997,
# day 451, sell 1 unit at price 25.700001, investment 0.312256 %, total balance 2095.029998,
# day 452: buy 1 unit at price 26.180000, total balance 2068.849998
# day 454: buy 1 unit at price 27.330000, total balance 2041.519998
# day 455, sell 1 unit at price 27.209999, investment 11.242846 %, total balance 2068.729997,
# day 456, sell 1 unit at price 27.340000, investment 9.843315 %, total balance 2096.069997,
# day 457: buy 1 unit at price 27.170000, total balance 2068.899997
# day 458, sell 1 unit at price 26.980000, investment 3.055768 %, total balance 2095.879997,
# day 459, sell 1 unit at price 27.160000, investment -0.622027 %, total balance 2123.039997,
# day 460: buy 1 unit at price 26.820000, total balance 2096.219997
# day 461, sell 1 unit at price 27.200001, investment 0.110420 %, total balance 2123.419998,
# day 462, sell 1 unit at price 26.440001, investment -1.416849 %, total balance 2149.859999,
# day 463: buy 1 unit at price 25.490000, total balance 2124.369999
# day 464, sell 1 unit at price 26.000000, investment 2.000785 %, total balance 2150.369999,
# day 471: buy 1 unit at price 27.500000, total balance 2122.869999
# day 472, sell 1 unit at price 26.520000, investment -3.563636 %, total balance 2149.389999,
# day 474: buy 1 unit at price 26.379999, total balance 2123.010000
# day 475, sell 1 unit at price 27.080000, investment 2.653529 %, total balance 2150.090000,
# day 477: buy 1 unit at price 27.299999, total balance 2122.790001
# day 478, sell 1 unit at price 27.080000, investment -0.805857 %, total balance 2149.870001,
# day 480: buy 1 unit at price 26.260000, total balance 2123.610001
# day 481: buy 1 unit at price 26.139999, total balance 2097.470002
# day 482: buy 1 unit at price 25.900000, total balance 2071.570002
# day 485, sell 1 unit at price 25.549999, investment -2.703736 %, total balance 2097.120001,
# day 486, sell 1 unit at price 25.120001, investment -3.902058 %, total balance 2122.240002,
# day 487: buy 1 unit at price 24.879999, total balance 2097.360003
# day 490: buy 1 unit at price 25.410000, total balance 2071.950003
# day 491: buy 1 unit at price 25.440001, total balance 2046.510002
# day 492: buy 1 unit at price 24.850000, total balance 2021.660002
# day 493, sell 1 unit at price 24.600000, investment -5.019305 %, total balance 2046.260002,
# day 495, sell 1 unit at price 23.389999, investment -5.988746 %, total balance 2069.650001,
# day 496: buy 1 unit at price 23.570000, total balance 2046.080001
# day 497: buy 1 unit at price 23.090000, total balance 2022.990001
# day 498: buy 1 unit at price 23.580000, total balance 1999.410001
# day 499, sell 1 unit at price 23.080000, investment -9.169618 %, total balance 2022.490001,
# day 500: buy 1 unit at price 22.910000, total balance 1999.580001
# day 501, sell 1 unit at price 24.129999, investment -5.149379 %, total balance 2023.710000,
# day 503, sell 1 unit at price 25.139999, investment 1.166998 %, total balance 2048.849999,
# day 504, sell 1 unit at price 24.780001, investment 5.133649 %, total balance 2073.630000,
# day 505: buy 1 unit at price 24.139999, total balance 2049.490001
# day 506, sell 1 unit at price 24.570000, investment 6.409701 %, total balance 2074.060001,
# day 508, sell 1 unit at price 23.250000, investment -1.399491 %, total balance 2097.310001,
# day 509, sell 1 unit at price 23.030001, investment 0.523793 %, total balance 2120.340002,
# day 511: buy 1 unit at price 23.660000, total balance 2096.680002
# day 512, sell 1 unit at price 24.000000, investment -0.579946 %, total balance 2120.680002,
# day 513: buy 1 unit at price 23.170000, total balance 2097.510002
# day 515: buy 1 unit at price 23.200001, total balance 2074.310001
# day 516, sell 1 unit at price 22.620001, investment -4.395600 %, total balance 2096.930002,
# day 517, sell 1 unit at price 22.379999, investment -3.409586 %, total balance 2119.310001,
# day 519: buy 1 unit at price 22.360001, total balance 2096.950000
# day 522, sell 1 unit at price 20.950001, investment -9.698275 %, total balance 2117.900001,
# day 523: buy 1 unit at price 20.910000, total balance 2096.990001
# day 524: buy 1 unit at price 20.260000, total balance 2076.730001
# day 525: buy 1 unit at price 20.139999, total balance 2056.590002
# day 526: buy 1 unit at price 20.200001, total balance 2036.390001
# day 527, sell 1 unit at price 20.090000, investment -10.152061 %, total balance 2056.480001,
# day 528, sell 1 unit at price 21.840000, investment 4.447633 %, total balance 2078.320001,
# day 529: buy 1 unit at price 20.920000, total balance 2057.400001
# day 531: buy 1 unit at price 21.799999, total balance 2035.600002
# day 532: buy 1 unit at price 21.320000, total balance 2014.280002
# day 533: buy 1 unit at price 20.850000, total balance 1993.430002
# day 534, sell 1 unit at price 21.030001, investment 3.800597 %, total balance 2014.460003,
# day 535: buy 1 unit at price 21.610001, total balance 1992.850002
# day 536, sell 1 unit at price 20.270000, investment 0.645487 %, total balance 2013.120002,
# day 538, sell 1 unit at price 20.059999, investment -0.693079 %, total balance 2033.180001,
# day 539, sell 1 unit at price 20.090000, investment -3.967495 %, total balance 2053.270001,
# day 540: buy 1 unit at price 20.760000, total balance 2032.510001
# day 541, sell 1 unit at price 20.459999, investment -6.146789 %, total balance 2052.970000,
# day 543, sell 1 unit at price 21.719999, investment 1.876168 %, total balance 2074.689999,
# day 545, sell 1 unit at price 21.870001, investment 4.892091 %, total balance 2096.560000,
# day 546, sell 1 unit at price 22.280001, investment 3.100416 %, total balance 2118.840001,
# day 548, sell 1 unit at price 22.549999, investment 8.622346 %, total balance 2141.390000,
# day 554: buy 1 unit at price 25.700001, total balance 2115.689999
# day 555, sell 1 unit at price 27.020000, investment 5.136183 %, total balance 2142.709999,
# day 565: buy 1 unit at price 29.410000, total balance 2113.299999
# day 566, sell 1 unit at price 28.850000, investment -1.904114 %, total balance 2142.149999,
# day 568: buy 1 unit at price 27.969999, total balance 2114.180000
# day 570: buy 1 unit at price 28.730000, total balance 2085.450000
# day 571, sell 1 unit at price 28.950001, investment 3.503761 %, total balance 2114.400001,
# day 573: buy 1 unit at price 27.990000, total balance 2086.410001
# day 575: buy 1 unit at price 27.830000, total balance 2058.580001
# day 576: buy 1 unit at price 27.520000, total balance 2031.060001
# day 577: buy 1 unit at price 28.120001, total balance 2002.940000
# day 578: buy 1 unit at price 27.299999, total balance 1975.640001
# day 579: buy 1 unit at price 27.360001, total balance 1948.280000
# day 580, sell 1 unit at price 26.950001, investment -6.195611 %, total balance 1975.230001,
# day 581, sell 1 unit at price 27.389999, investment -2.143626 %, total balance 2002.620000,
# day 582: buy 1 unit at price 28.160000, total balance 1974.460000
# day 583: buy 1 unit at price 27.860001, total balance 1946.599999
# day 584, sell 1 unit at price 27.570000, investment -0.934244 %, total balance 1974.169999,
# day 585, sell 1 unit at price 28.219999, investment 2.543601 %, total balance 2002.389998,
# day 586: buy 1 unit at price 27.750000, total balance 1974.639998
# day 587, sell 1 unit at price 27.770000, investment -1.244669 %, total balance 2002.409998,
# day 588: buy 1 unit at price 27.459999, total balance 1974.949999
# day 589, sell 1 unit at price 27.459999, investment 0.586081 %, total balance 2002.409998,
# day 590, sell 1 unit at price 26.990000, investment -1.352343 %, total balance 2029.399998,
# day 591: buy 1 unit at price 27.420000, total balance 2001.979998
# day 592, sell 1 unit at price 28.010000, investment -0.532670 %, total balance 2029.989998,
# day 594: buy 1 unit at price 28.180000, total balance 2001.809998
# day 595, sell 1 unit at price 28.889999, investment 3.697049 %, total balance 2030.699997,
# day 596: buy 1 unit at price 28.530001, total balance 2002.169996
# day 597: buy 1 unit at price 28.760000, total balance 1973.409996
# day 598, sell 1 unit at price 28.870001, investment 4.036040 %, total balance 2002.279997,
# day 599, sell 1 unit at price 29.150000, investment 6.154410 %, total balance 2031.429997,
# day 600, sell 1 unit at price 29.150000, investment 6.309263 %, total balance 2060.579997,
# day 602, sell 1 unit at price 29.650000, investment 5.216466 %, total balance 2090.229997,
# day 603, sell 1 unit at price 29.230000, investment 2.453554 %, total balance 2119.459997,
# day 604: buy 1 unit at price 29.309999, total balance 2090.149998
# day 605: buy 1 unit at price 29.330000, total balance 2060.819998
# day 606, sell 1 unit at price 29.309999, investment 1.912375 %, total balance 2090.129997,
# day 607, sell 1 unit at price 28.900000, investment -1.398837 %, total balance 2119.029997,
# day 608: buy 1 unit at price 28.030001, total balance 2090.999996
# day 609, sell 1 unit at price 28.230000, investment -3.750426 %, total balance 2119.229996,
# day 610: buy 1 unit at price 28.150000, total balance 2091.079996
# day 612, sell 1 unit at price 28.480000, investment 1.605419 %, total balance 2119.559996,
# day 614: buy 1 unit at price 29.120001, total balance 2090.439995
# day 616: buy 1 unit at price 28.930000, total balance 2061.509995
# day 617, sell 1 unit at price 28.990000, investment 2.984014 %, total balance 2090.499995,
# day 618: buy 1 unit at price 28.580000, total balance 2061.919995
# day 619, sell 1 unit at price 28.190001, investment -3.193681 %, total balance 2090.109996,
# day 620: buy 1 unit at price 27.910000, total balance 2062.199996
# day 621: buy 1 unit at price 27.900000, total balance 2034.299996
# day 622, sell 1 unit at price 27.820000, investment -3.836848 %, total balance 2062.119996,
# day 623: buy 1 unit at price 26.940001, total balance 2035.179995
# day 624, sell 1 unit at price 26.530001, investment -7.172845 %, total balance 2061.709996,
# day 626: buy 1 unit at price 26.860001, total balance 2034.849995
# day 627, sell 1 unit at price 27.230000, investment -2.436403 %, total balance 2062.079995,
# day 628: buy 1 unit at price 27.049999, total balance 2035.029996
# day 629, sell 1 unit at price 27.400000, investment -1.792115 %, total balance 2062.429996,
# day 631: buy 1 unit at price 26.930000, total balance 2035.499996
# day 632, sell 1 unit at price 27.240000, investment 1.113582 %, total balance 2062.739996,
# day 634: buy 1 unit at price 26.020000, total balance 2036.719996
# day 635, sell 1 unit at price 26.510000, investment -1.303057 %, total balance 2063.229996,
# day 636: buy 1 unit at price 27.420000, total balance 2035.809996
# day 637: buy 1 unit at price 27.610001, total balance 2008.199995
# day 638: buy 1 unit at price 28.190001, total balance 1980.009994
# day 639, sell 1 unit at price 27.410000, investment 1.330873 %, total balance 2007.419994,
# day 640, sell 1 unit at price 27.110001, investment 0.668403 %, total balance 2034.529995,
# day 642: buy 1 unit at price 27.590000, total balance 2006.939995
# day 643, sell 1 unit at price 27.770000, investment 6.725596 %, total balance 2034.709995,
# day 645, sell 1 unit at price 30.629999, investment 11.706780 %, total balance 2065.339994,
# day 646, sell 1 unit at price 30.600000, investment 10.829406 %, total balance 2095.939994,
# day 647, sell 1 unit at price 30.629999, investment 8.655544 %, total balance 2126.569993,
# day 648: buy 1 unit at price 30.559999, total balance 2096.009994
# day 649: buy 1 unit at price 30.490000, total balance 2065.519994
# day 651, sell 1 unit at price 30.080000, investment 9.025009 %, total balance 2095.599994,
# day 652, sell 1 unit at price 30.600000, investment 0.130893 %, total balance 2126.199994,
# day 653: buy 1 unit at price 29.920000, total balance 2096.279994
# day 654, sell 1 unit at price 29.940001, investment -1.803867 %, total balance 2126.219995,
# day 655, sell 1 unit at price 29.260000, investment -2.205882 %, total balance 2155.479995,
# day 657: buy 1 unit at price 29.420000, total balance 2126.059995
# day 658: buy 1 unit at price 28.459999, total balance 2097.599996
# day 659: buy 1 unit at price 27.830000, total balance 2069.769996
# day 662, sell 1 unit at price 29.030001, investment -1.325625 %, total balance 2098.799997,
# day 664: buy 1 unit at price 28.870001, total balance 2069.929996
# day 665: buy 1 unit at price 29.400000, total balance 2040.529996
# day 666: buy 1 unit at price 29.650000, total balance 2010.879996
# day 667: buy 1 unit at price 29.799999, total balance 1981.079997
# day 669: buy 1 unit at price 29.750000, total balance 1951.329997
# day 670, sell 1 unit at price 29.660000, investment 4.216448 %, total balance 1980.989997,
# day 671, sell 1 unit at price 30.090000, investment 8.120733 %, total balance 2011.079997,
# day 672, sell 1 unit at price 29.910000, investment 3.602352 %, total balance 2040.989997,
# day 673: buy 1 unit at price 29.660000, total balance 2011.329997
# day 674: buy 1 unit at price 29.750000, total balance 1981.579997
# day 675: buy 1 unit at price 30.100000, total balance 1951.479997
# day 676, sell 1 unit at price 30.160000, investment 2.585034 %, total balance 1981.639997,
# day 677: buy 1 unit at price 29.629999, total balance 1952.009998
# day 678, sell 1 unit at price 29.790001, investment 0.472179 %, total balance 1981.799999,
# day 679: buy 1 unit at price 29.820000, total balance 1951.979999
# day 681, sell 1 unit at price 30.510000, investment 2.382554 %, total balance 1982.489999,
# day 682, sell 1 unit at price 30.500000, investment 2.521008 %, total balance 2012.989999,
# day 683: buy 1 unit at price 30.530001, total balance 1982.459998
# day 685: buy 1 unit at price 30.830000, total balance 1951.629998
# day 686, sell 1 unit at price 30.299999, investment 2.157785 %, total balance 1981.929997,
# day 687: buy 1 unit at price 31.000000, total balance 1950.929997
# day 688: buy 1 unit at price 30.950001, total balance 1919.979996
# day 689, sell 1 unit at price 31.000000, investment 4.201681 %, total balance 1950.979996,
# day 690, sell 1 unit at price 31.610001, investment 5.016615 %, total balance 1982.589997,
# day 691, sell 1 unit at price 31.910000, investment 7.694907 %, total balance 2014.499997,
# day 692: buy 1 unit at price 31.840000, total balance 1982.659997
# day 693: buy 1 unit at price 31.770000, total balance 1950.889997
# day 694: buy 1 unit at price 31.500000, total balance 1919.389997
# day 695, sell 1 unit at price 31.660000, investment 6.170355 %, total balance 1951.049997,
# day 696: buy 1 unit at price 31.330000, total balance 1919.719997
# day 697: buy 1 unit at price 30.629999, total balance 1889.089998
# day 698, sell 1 unit at price 31.320000, investment 2.587615 %, total balance 1920.409998,
# day 700, sell 1 unit at price 30.799999, investment -0.097311 %, total balance 1951.209997,
# day 701, sell 1 unit at price 31.090000, investment 0.290323 %, total balance 1982.299997,
# day 702: buy 1 unit at price 32.220001, total balance 1950.079996
# day 703: buy 1 unit at price 31.629999, total balance 1918.449997
# day 705, sell 1 unit at price 32.459999, investment 4.878830 %, total balance 1950.909996,
# day 706, sell 1 unit at price 32.240002, investment 1.256288 %, total balance 1983.149998,
# day 708, sell 1 unit at price 31.500000, investment -0.849858 %, total balance 2014.649998,
# day 709, sell 1 unit at price 31.900000, investment 1.269841 %, total balance 2046.549998,
# day 710: buy 1 unit at price 31.350000, total balance 2015.199998
# day 712, sell 1 unit at price 31.549999, investment 0.702199 %, total balance 2046.749997,
# day 713, sell 1 unit at price 31.600000, investment 3.166833 %, total balance 2078.349997,
# day 714: buy 1 unit at price 31.549999, total balance 2046.799998
# day 715, sell 1 unit at price 31.600000, investment -1.924274 %, total balance 2078.399998,
# day 716, sell 1 unit at price 31.799999, investment 0.537464 %, total balance 2110.199997,
# day 717, sell 1 unit at price 32.099998, investment 2.392338 %, total balance 2142.299995,
# day 719, sell 1 unit at price 31.700001, investment 0.475442 %, total balance 2173.999996,
# day 724: buy 1 unit at price 30.600000, total balance 2143.399996
# day 726: buy 1 unit at price 31.299999, total balance 2112.099997
# day 727, sell 1 unit at price 32.099998, investment 4.901954 %, total balance 2144.199995,
# day 728: buy 1 unit at price 32.250000, total balance 2111.949995
# day 729, sell 1 unit at price 33.400002, investment 6.709275 %, total balance 2145.349997,
# day 730, sell 1 unit at price 33.400002, investment 3.565898 %, total balance 2178.749999,
# day 734: buy 1 unit at price 34.500000, total balance 2144.249999
# day 735, sell 1 unit at price 35.500000, investment 2.898551 %, total balance 2179.749999,
# day 736: buy 1 unit at price 35.049999, total balance 2144.700000
# day 737, sell 1 unit at price 34.750000, investment -0.855917 %, total balance 2179.450000,
# day 738: buy 1 unit at price 34.700001, total balance 2144.749999
# day 739, sell 1 unit at price 34.900002, investment 0.576372 %, total balance 2179.650001,
# day 741: buy 1 unit at price 33.900002, total balance 2145.749999
# day 742, sell 1 unit at price 34.549999, investment 1.917395 %, total balance 2180.299998,
# day 744: buy 1 unit at price 33.500000, total balance 2146.799998
# day 745, sell 1 unit at price 32.250000, investment -3.731343 %, total balance 2179.049998,
# day 749: buy 1 unit at price 32.099998, total balance 2146.950000
# day 750, sell 1 unit at price 32.599998, investment 1.557632 %, total balance 2179.549998,
# day 752: buy 1 unit at price 32.000000, total balance 2147.549998
# day 753, sell 1 unit at price 31.750000, investment -0.781250 %, total balance 2179.299998,
# day 754: buy 1 unit at price 32.000000, total balance 2147.299998
# day 755: buy 1 unit at price 31.900000, total balance 2115.399998
# day 756: buy 1 unit at price 33.200001, total balance 2082.199997
# day 757, sell 1 unit at price 33.450001, investment 4.531253 %, total balance 2115.649998,
# day 758, sell 1 unit at price 34.700001, investment 8.777433 %, total balance 2150.349999,
# day 759: buy 1 unit at price 35.099998, total balance 2115.250001
# day 760, sell 1 unit at price 35.299999, investment 6.325295 %, total balance 2150.550000,
# day 761, sell 1 unit at price 35.450001, investment 0.997160 %, total balance 2186.000001,
# day 763: buy 1 unit at price 34.200001, total balance 2151.800000
# day 764, sell 1 unit at price 33.650002, investment -1.608184 %, total balance 2185.450002,
# ...
# day 1897, sell 1 unit at price 51.959999, investment 2101.694873 %, total balance 2491.300014,
# day 1899, sell 1 unit at price 45.070000, investment 1826.068376 %, total balance 2536.370014,
# day 1900, sell 1 unit at price 47.939999, investment 1975.324632 %, total balance 2584.310013,
# day 1901, sell 1 unit at price 46.189999, investment 1755.020040 %, total balance 2630.500012,
# day 1903: buy 1 unit at price 39.349998, total balance 2591.150014
# day 1904, sell 1 unit at price 33.430000, investment 786.737401 %, total balance 2624.580014,
# day 1908, sell 1 unit at price 43.090000, investment 1127.635328 %, total balance 2667.670014,
# day 1910: buy 1 unit at price 37.240002, total balance 2630.430012
# day 1911, sell 1 unit at price 36.990002, investment 1081.789201 %, total balance 2667.420014,
# day 1912: buy 1 unit at price 40.290001, total balance 2627.130013
# day 1913, sell 1 unit at price 38.009998, investment 1122.186431 %, total balance 2665.140011,
# day 1915, sell 1 unit at price 38.130001, investment 1069.631933 %, total balance 2703.270012,
# day 1916, sell 1 unit at price 37.020000, investment 1005.074627 %, total balance 2740.290012,
# day 1918, sell 1 unit at price 33.590000, investment 648.106904 %, total balance 2773.880012,
# day 1919, sell 1 unit at price 29.840000, investment 722.038567 %, total balance 2803.720012,
# day 1921: buy 1 unit at price 32.700001, total balance 2771.020011
# day 1922, sell 1 unit at price 33.799999, investment 749.246206 %, total balance 2804.820010,
# day 1923, sell 1 unit at price 31.750000, investment 722.538860 %, total balance 2836.570010,
# day 1926, sell 1 unit at price 33.470001, investment 718.337433 %, total balance 2870.040011,
# day 1930, sell 1 unit at price 33.820000, investment 762.755102 %, total balance 2903.860011,
# day 1932, sell 1 unit at price 36.779999, investment 1186.013951 %, total balance 2940.640010,
# day 1933, sell 1 unit at price 44.259998, investment 1608.880232 %, total balance 2984.900008,
# day 1934, sell 1 unit at price 43.959999, investment 1617.187461 %, total balance 3028.860007,
# day 1935, sell 1 unit at price 40.310001, investment 1505.976135 %, total balance 3069.170008,
# day 1936, sell 1 unit at price 40.840000, investment 1608.786611 %, total balance 3110.010008,
# day 1937: buy 1 unit at price 43.330002, total balance 3066.680006
# day 1938, sell 1 unit at price 47.130001, investment 1958.078646 %, total balance 3113.810007,
# day 1939, sell 1 unit at price 43.689999, investment 1922.685139 %, total balance 3157.500006,
# day 1940, sell 1 unit at price 44.380001, investment 2107.960249 %, total balance 3201.880007,
# day 1941, sell 1 unit at price 44.020000, investment 2090.049751 %, total balance 3245.900007,
# day 1943, sell 1 unit at price 47.400002, investment 2114.953364 %, total balance 3293.300009,
# day 1944, sell 1 unit at price 48.520000, investment 2105.454545 %, total balance 3341.820009,
# day 1946, sell 1 unit at price 51.689999, investment 2157.205197 %, total balance 3393.510008,
# day 1947: buy 1 unit at price 47.299999, total balance 3346.210009
# day 1948, sell 1 unit at price 46.840000, investment 2048.623853 %, total balance 3393.050009,
# day 1949, sell 1 unit at price 46.040001, investment 2011.926651 %, total balance 3439.090010,
# day 1951, sell 1 unit at price 40.290001, investment 1252.013456 %, total balance 3479.380011,
# day 1953, sell 1 unit at price 40.080002, investment 1041.880399 %, total balance 3519.460013,
# day 1954: buy 1 unit at price 39.980000, total balance 3479.480013
# day 1955: buy 1 unit at price 40.009998, total balance 3439.470015
# day 1956, sell 1 unit at price 39.299999, investment 338.127079 %, total balance 3478.770014,
# day 1959: buy 1 unit at price 38.060001, total balance 3440.710013
# day 1960: buy 1 unit at price 38.459999, total balance 3402.250014
# day 1962, sell 1 unit at price 37.060001, investment 442.606164 %, total balance 3439.310015,
# day 1963, sell 1 unit at price 36.830002, investment 569.636400 %, total balance 3476.140017,
# day 1964, sell 1 unit at price 38.139999, investment 582.289785 %, total balance 3514.280016,
# day 1965: buy 1 unit at price 37.189999, total balance 3477.090017
# day 1966, sell 1 unit at price 37.250000, investment 468.702290 %, total balance 3514.340017,
# day 1967, sell 1 unit at price 36.820000, investment 359.675406 %, total balance 3551.160017,
# day 1969: buy 1 unit at price 40.070000, total balance 3511.090017
# day 1970, sell 1 unit at price 40.740002, investment 343.790871 %, total balance 3551.830019,
# day 1971, sell 1 unit at price 43.029999, investment 381.858891 %, total balance 3594.860018,
# day 1972, sell 1 unit at price 40.799999, investment 288.571419 %, total balance 3635.660017,
# day 1974, sell 1 unit at price 39.240002, investment 335.033282 %, total balance 3674.900019,
# day 1977, sell 1 unit at price 36.049999, investment 252.050771 %, total balance 3710.950018,
# day 1979, sell 1 unit at price 35.230000, investment 245.053869 %, total balance 3746.180018,
# day 1981: buy 1 unit at price 37.070000, total balance 3709.110018
# day 1984, sell 1 unit at price 40.049999, investment 327.884605 %, total balance 3749.160017,
# day 1986, sell 1 unit at price 45.060001, investment 341.764716 %, total balance 3794.220018,
# day 1987, sell 1 unit at price 39.930000, investment 307.865169 %, total balance 3834.150018,
# day 1989, sell 1 unit at price 39.459999, investment 322.032075 %, total balance 3873.610017,
# day 1991, sell 1 unit at price 42.680000, investment 331.111111 %, total balance 3916.290017,
# day 1992, sell 1 unit at price 42.599998, investment 356.591618 %, total balance 3958.890015,
# day 1993, sell 1 unit at price 42.130001, investment 353.987080 %, total balance 4001.020016,
# day 1994, sell 1 unit at price 40.410000, investment 304.504505 %, total balance 4041.430016,
# day 1995: buy 1 unit at price 40.869999, total balance 4000.560017
# day 1996, sell 1 unit at price 41.240002, investment 280.092184 %, total balance 4041.800019,
# day 1997, sell 1 unit at price 39.160000, investment 327.044711 %, total balance 4080.960019,
# day 1999, sell 1 unit at price 37.630001, investment 189.907558 %, total balance 4118.590020,
# day 2001, sell 1 unit at price 33.939999, investment 148.099408 %, total balance 4152.530019,
# day 2006, sell 1 unit at price 31.040001, investment -21.118164 %, total balance 4183.570020,
# day 2007, sell 1 unit at price 32.349998, investment -13.131052 %, total balance 4215.920018,
# day 2008: buy 1 unit at price 29.459999, total balance 4186.460019
# day 2011, sell 1 unit at price 24.500000, investment -39.190868 %, total balance 4210.960019,
# day 2013: buy 1 unit at price 24.450001, total balance 4186.510018
# day 2014, sell 1 unit at price 29.120001, investment -10.948012 %, total balance 4215.630019,
# day 2016: buy 1 unit at price 30.299999, total balance 4185.330020
# day 2017, sell 1 unit at price 28.680000, investment -33.810296 %, total balance 4214.010020,
# day 2018: buy 1 unit at price 28.520000, total balance 4185.490020
# day 2021, sell 1 unit at price 27.950001, investment -40.909088 %, total balance 4213.440021,
# day 2022, sell 1 unit at price 28.940001, investment -27.613804 %, total balance 4242.380022,
# day 2024, sell 1 unit at price 26.520000, investment -33.716568 %, total balance 4268.900022,
# day 2025, sell 1 unit at price 25.490000, investment -33.026802 %, total balance 4294.390022,
# day 2029, sell 1 unit at price 22.780001, investment -40.769627 %, total balance 4317.170023,
# day 2032, sell 1 unit at price 20.660000, investment -44.447431 %, total balance 4337.830023,
# day 2040, sell 1 unit at price 15.940000, investment -60.219616 %, total balance 4353.770023,
# day 2041: buy 1 unit at price 14.520000, total balance 4339.250023
# day 2042: buy 1 unit at price 15.060000, total balance 4324.190023
# day 2043, sell 1 unit at price 16.059999, investment -56.676561 %, total balance 4340.250022,
# day 2044: buy 1 unit at price 16.860001, total balance 4323.390021
# day 2045: buy 1 unit at price 15.420000, total balance 4307.970021
# day 2046, sell 1 unit at price 14.870000, investment -63.616344 %, total balance 4322.840021,
# day 2050, sell 1 unit at price 18.940001, investment -35.709431 %, total balance 4341.780022,
# day 2051, sell 1 unit at price 18.590000, investment -23.967283 %, total balance 4360.370022,
# day 2053, sell 1 unit at price 17.750000, investment -41.419140 %, total balance 4378.120022,
# day 2054, sell 1 unit at price 19.480000, investment -31.697055 %, total balance 4397.600022,
# day 2055, sell 1 unit at price 19.670000, investment 35.468320 %, total balance 4417.270022,
# day 2057, sell 1 unit at price 17.900000, investment 18.857902 %, total balance 4435.170022,
# day 2058, sell 1 unit at price 16.469999, investment -2.313179 %, total balance 4451.640021,
# day 2059: buy 1 unit at price 15.730000, total balance 4435.910021
# day 2060, sell 1 unit at price 17.680000, investment 14.656291 %, total balance 4453.590021,
# day 2062, sell 1 unit at price 18.860001, investment 19.898290 %, total balance 4472.450022,
# day 2064: buy 1 unit at price 18.530001, total balance 4453.920021
# day 2065, sell 1 unit at price 18.059999, investment -2.536438 %, total balance 4471.980020,
# day 2067: buy 1 unit at price 15.210000, total balance 4456.770020
# day 2068, sell 1 unit at price 15.390000, investment 1.183432 %, total balance 4472.160020,
# day 2071: buy 1 unit at price 14.300000, total balance 4457.860020
# day 2072: buy 1 unit at price 13.560000, total balance 4444.300020
# day 2075, sell 1 unit at price 15.190000, investment 6.223776 %, total balance 4459.490020,
# day 2076, sell 1 unit at price 15.800000, investment 16.519174 %, total balance 4475.290020,
# day 2077: buy 1 unit at price 15.860000, total balance 4459.430020
# day 2078, sell 1 unit at price 18.260000, investment 15.132409 %, total balance 4477.690020,
# day 2092: buy 1 unit at price 18.719999, total balance 4458.970021
# day 2093, sell 1 unit at price 17.420000, investment -6.944439 %, total balance 4476.390021,
# day 2104: buy 1 unit at price 15.640000, total balance 4460.750021
# day 2105: buy 1 unit at price 15.300000, total balance 4445.450021
# day 2107, sell 1 unit at price 15.510000, investment -0.831202 %, total balance 4460.960021,
# day 2108, sell 1 unit at price 15.720000, investment 2.745098 %, total balance 4476.680021,
# day 2109: buy 1 unit at price 14.690000, total balance 4461.990021
# day 2110: buy 1 unit at price 13.760000, total balance 4448.230021
# day 2111, sell 1 unit at price 12.520000, investment -14.771954 %, total balance 4460.750021,
# day 2118: buy 1 unit at price 12.760000, total balance 4447.990021
# day 2119: buy 1 unit at price 13.080000, total balance 4434.910021
# day 2121, sell 1 unit at price 11.580000, investment -15.843023 %, total balance 4446.490021,
# day 2122, sell 1 unit at price 10.390000, investment -18.573668 %, total balance 4456.880021,
# day 2124: buy 1 unit at price 12.230000, total balance 4444.650021
# day 2125, sell 1 unit at price 14.430000, investment 10.321101 %, total balance 4459.080021,
# day 2126, sell 1 unit at price 14.340000, investment 17.252657 %, total balance 4473.420021,
# day 2127: buy 1 unit at price 12.810000, total balance 4460.610021
# day 2128: buy 1 unit at price 13.300000, total balance 4447.310021
# day 2129: buy 1 unit at price 12.450000, total balance 4434.860021
# day 2130: buy 1 unit at price 11.950000, total balance 4422.910021
# day 2132, sell 1 unit at price 13.520000, investment 5.542545 %, total balance 4436.430021,
# day 2133, sell 1 unit at price 12.780000, investment -3.909774 %, total balance 4449.210021,
# day 2134, sell 1 unit at price 12.430000, investment -0.160643 %, total balance 4461.640021,
# day 2135: buy 1 unit at price 11.480000, total balance 4450.160021
# day 2136, sell 1 unit at price 11.920000, investment -0.251046 %, total balance 4462.080021,
# day 2138: buy 1 unit at price 11.790000, total balance 4450.290021
# day 2139, sell 1 unit at price 12.530000, investment 9.146341 %, total balance 4462.820021,
# day 2140: buy 1 unit at price 12.500000, total balance 4450.320021
# day 2141, sell 1 unit at price 12.600000, investment 6.870229 %, total balance 4462.920021,
# day 2142: buy 1 unit at price 12.050000, total balance 4450.870021
# day 2143, sell 1 unit at price 12.470000, investment -0.240000 %, total balance 4463.340021,
# day 2144, sell 1 unit at price 14.130000, investment 17.261411 %, total balance 4477.470021,
# day 2146: buy 1 unit at price 13.650000, total balance 4463.820021
# day 2147, sell 1 unit at price 13.550000, investment -0.732601 %, total balance 4477.370021,
# day 2148: buy 1 unit at price 13.530000, total balance 4463.840021
# day 2149, sell 1 unit at price 12.780000, investment -5.543237 %, total balance 4476.620021,
# day 2151: buy 1 unit at price 14.480000, total balance 4462.140021
# day 2152, sell 1 unit at price 14.660000, investment 1.243094 %, total balance 4476.800021,
# day 2153: buy 1 unit at price 14.950000, total balance 4461.850021
# day 2154, sell 1 unit at price 15.600000, investment 4.347826 %, total balance 4477.450021,
# day 2165: buy 1 unit at price 14.480000, total balance 4462.970021
# day 2166, sell 1 unit at price 14.580000, investment 0.690608 %, total balance 4477.550021,
# day 2170: buy 1 unit at price 18.209999, total balance 4459.340022
# day 2171, sell 1 unit at price 18.660000, investment 2.471175 %, total balance 4478.000022,
# day 2174: buy 1 unit at price 22.450001, total balance 4455.550021
# day 2175, sell 1 unit at price 23.670000, investment 5.434294 %, total balance 4479.220021,
# day 2177: buy 1 unit at price 24.440001, total balance 4454.780020
# day 2178, sell 1 unit at price 24.209999, investment -0.941088 %, total balance 4478.990019,
# day 2181: buy 1 unit at price 19.290001, total balance 4459.700018
# day 2182: buy 1 unit at price 18.020000, total balance 4441.680018
# day 2183, sell 1 unit at price 10.460000, investment -45.775016 %, total balance 4452.140018,
# day 2194: buy 1 unit at price 8.390000, total balance 4443.750018
# day 2195, sell 1 unit at price 8.640000, investment -52.053274 %, total balance 4452.390018,
# day 2197, sell 1 unit at price 10.220000, investment 21.811681 %, total balance 4462.610018,
# day 2198: buy 1 unit at price 9.720000, total balance 4452.890018
# day 2199: buy 1 unit at price 9.910000, total balance 4442.980018
# day 2200, sell 1 unit at price 9.880000, investment 1.646091 %, total balance 4452.860018,
# day 2201: buy 1 unit at price 8.980000, total balance 4443.880018
# day 2202, sell 1 unit at price 9.180000, investment -7.366297 %, total balance 4453.060018,
# day 2203, sell 1 unit at price 8.710000, investment -3.006682 %, total balance 4461.770018,
# day 2207: buy 1 unit at price 6.830000, total balance 4454.940018
# day 2214, sell 1 unit at price 7.330000, investment 7.320644 %, total balance 4462.270018,
# day 2217: buy 1 unit at price 6.350000, total balance 4455.920018
# day 2218: buy 1 unit at price 6.120000, total balance 4449.800018
# day 2219: buy 1 unit at price 5.850000, total balance 4443.950018
# day 2220: buy 1 unit at price 6.040000, total balance 4437.910018
# day 2221, sell 1 unit at price 6.000000, investment -5.511811 %, total balance 4443.910018,
# day 2222: buy 1 unit at price 6.360000, total balance 4437.550018
# day 2223: buy 1 unit at price 6.510000, total balance 4431.040018
# day 2224, sell 1 unit at price 6.110000, investment -0.163399 %, total balance 4437.150018,
# day 2225: buy 1 unit at price 6.350000, total balance 4430.800018
# day 2226, sell 1 unit at price 6.490000, investment 10.940171 %, total balance 4437.290018,
# day 2228, sell 1 unit at price 6.750000, investment 11.754967 %, total balance 4444.040018,
# day 2230: buy 1 unit at price 6.510000, total balance 4437.530018
# day 2231, sell 1 unit at price 6.510000, investment 2.358491 %, total balance 4444.040018,
# day 2233, sell 1 unit at price 6.150000, investment -5.529954 %, total balance 4450.190018,
# day 2234: buy 1 unit at price 5.810000, total balance 4444.380018
# day 2235: buy 1 unit at price 5.700000, total balance 4438.680018

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
